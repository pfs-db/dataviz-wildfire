# %%
import waldbrand
from viz import df_viz

# %%
waldbrand_obj = waldbrand.WildFire()
df = waldbrand_obj.get_all_ffa()
viz_obj = df_viz.DataFrameVisualizer(df)

# %%
viz_obj.plot_scatter("Year", "Zusammen Anzahl")

# %%
viz_obj.plot_histogram("Zusammen Anzahl")

# %%
# viz_obj.plot_interactive_density_heatmap("Year", "Zusammen Anzahl ")
grouped_by_land = df.groupby('Land')

# %%
grouped_by_land.mean(numeric_only=True)
# Out:
#                         Nadelholz Flaeche (ha)  Zusammen Anzahl  \
# Land
# Baden-Wuerttemberg                    5.878889        36.296296
# Baden-Wuerttemberg                     2.000000        18.000000
# Bayern                               45.622857        71.035714
# Berlin                                7.048214        19.321429
# Brandenburg                         196.153929       338.321429
# Bremen                                0.000000         0.035714
# Deutschland                         428.566071      1002.892857
# Frueheres Bundesgebiet              115.756667       419.222222
# Frueheres Bundesgebiet                50.700000       266.000000
# Hamburg                               0.007500         0.107143
# Hessen                                9.989643        65.814815
# Mecklenburg-Vorpommern               53.469643        52.785714
# Neue Laender                        312.208148       576.629630
# Neue Laender                         267.500000       552.000000
# Niedersachsen                        27.694286       117.464286
# Nordrhein-Westfalen                  11.812143        59.750000
# Rheinland-Pfalz                       5.999643        43.000000
# Saarland                              2.651071         6.857143
# Sachsen                              38.045357        97.964286
# Sachsen-Anhalt                       29.223571        87.000000
# Schleswig-Holstein                    0.621786         4.357143
# Thueringen                            3.942222        28.000000
# Thueringen                             1.200000        19.000000
#
#                         Zusammen Flaeche (ha)
# Land
# Baden-Wuerttemberg                  10.380370
# Baden-Wuerttemberg                    7.500000
# Bayern                              62.137143
# Berlin                               8.226786
# Brandenburg                        313.435000
# Bremen                               0.014286
# Deutschland                        651.800714
# Frueheres Bundesgebiet             175.894444
# Frueheres Bundesgebiet               85.200000
# Hamburg                              0.011429
# Hessen                              15.141481
# Mecklenburg-Vorpommern              58.588571
# Neue Laender                       474.910370
# Neue Laender                        453.300000
# Niedersachsen                       36.224643
# Nordrhein-Westfalen                 21.672500
# Rheinland-Pfalz                     15.168214
# Saarland                             5.189643
# Sachsen                             69.821071
# Sachsen-Anhalt                      41.493571
# Schleswig-Holstein                   1.332500
# Thueringen                           6.637407
# Thueringen                            1.300000
